# %%
import networkx as nx
import pickle

G: nx.Graph
with open("project_3_graph.pkl", "rb") as f:
    G = pickle.load(f)
nx.draw(G)

# %%
G = nx.read_graphml("project_3_graph.graphml")
pos = nx.nx_pydot.graphviz_layout(G, prog="neato")
nx.draw(G, pos)
print([edge for edge in G.edges()])
# Out:
# [('1', '306'), ('1', '1'), ('1', '106'), ('1', '290'), ('1', '22'), ('1', '272'), ('1', '308'), ('1', '5'), ('1', '87'), ('1', '88'), ('1', '222'), ('1', '157'), ('1', '115'), ('1', '102'), ('1', '314'), ('1', '317'), ('1', '318'), ('1', '319'), ('1', '321'), ('1', '322'), ('1', '324'), ('1', '333'), ('1', '334'), ('1', '335'), ('1', '337'), ('1', '338'), ('1', '339'), ('1', '340'), ('1', '342'), ('1', '345'), ('1', '121'), ('1', '211'), ('1', '364'), ('1', '378'), ('1', '383'), ('1', '389'), ('1', '394'), ('1', '395'), ('1', '396'), ('1', '397'), ('1', '398'), ('1', '405'), ('1', '412'), ('1', '418'), ('1', '419'), ('1', '420'), ('1', '422'), ('1', '423'), ('1', '36'), ('1', '127'), ('1', '303'), ('1', '425'), ('1', '429'), ('1', '430'), ('1', '449'), ('1', '451'), ('1', '457'), ('1', '458'), ('1', '465'), ('1', '142'), ('1', '113'), ('1', '307'), ('1', '145'), ('1', '208'), ('1', '48'), ('1', '21'), ('1', '304'), ('1', '467'), ('1', '473'), ('1', '474'), ('1', '483'), ('1', '485'),
# ...

# %%
for node in G.nodes():
    print(f"node id = {G.nodes[node]['node_ID']} node type = {G.nodes[node]['node_type']} node_value = {G.nodes[node]['node_value']}")
# Out:
# node id = 530 node type = person node_value = TA
# node id = 0 node type = person node_value = TA
# node id = 80 node type = person node_value = Student
# node id = 531 node type = person node_value = Student
# node id = 162 node type = person node_value = Student
# node id = 7 node type = person node_value = Student
# node id = 532 node type = person node_value = Student
# node id = 533 node type = person node_value = Student
# node id = 534 node type = person node_value = Student
# node id = 535 node type = person node_value = Student
# node id = 536 node type = person node_value = Student
# node id = 537 node type = person node_value = Student
# node id = 538 node type = person node_value = Student
# node id = 539 node type = person node_value = Student
# node id = 170 node type = person node_value = Student
# node id = 158 node type = person node_value = Student
# node id = 97 node type = person node_value = Student
# node id = 172 node type = person node_value = Student
# ...
